# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.2'

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
import keras
from glob import glob
import matplotlib.pyplot as plt

# %%
 IMAGE_SIZE = [224,224]

# %%
train_path = '/content/drive/MyDrive/Dataset/train'
valid_path = '/content/drive/MyDrive/Dataset/valid'

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# don't train existing weights
for layer in vgg16.layers:
    layer.trainable = False

# %%
folders = glob('/content/drive/MyDrive/Dataset/train/*')

# %%
folders
# Out:
# ['/content/drive/MyDrive/Dataset/train/Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Early_blight',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Bacterial_spot',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Tomato_mosaic_virus',
#  '/content/drive/MyDrive/Dataset/train/Tomato___healthy',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Late_blight',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Target_Spot',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Leaf_Mold',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Spider_mites Two-spotted_spider_mite',
#  '/content/drive/MyDrive/Dataset/train/Tomato___Septoria_leaf_spot']

# %%
# our layers - you can add more if you want
x = Flatten()(vgg16.output)

# %%
len(folders)
# Out:
# 10

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=vgg16.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 10)                250890
#
# =================================================================
# Total params: 14,965,578
# Trainable params: 250,890
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(optimizer="sgd",
              loss="categorical_crossentropy",
              metrics=[keras.metrics.Precision(name='Precision'),
                       keras.metrics.Recall(name='Recall'), 
                       keras.metrics.SpecificityAtSensitivity(0.5, name='Specificity'),
                       keras.metrics.SensitivityAtSpecificity(0.5, name='Sensitivity'),
                       'accuracy'])

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Dataset/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 18345 images belonging to 10 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Dataset/valid',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 4585 images belonging to 10 classes.

# %%
# fit the model
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=20,
  steps_per_epoch=len(training_set))
# Out:
# Epoch 1/20
# 574/574 [==============================] - 4766s 8s/step - loss: 7.8509 - Precision: 0.4249 - Recall: 0.4050 - Specificity: 0.8962 - Sensitivity: 0.6197 - accuracy: 0.4150 - val_loss: 4.8042 - val_Precision: 0.5313 - val_Recall: 0.5093 - val_Specificity: 0.9519 - val_Sensitivity: 0.7047 - val_accuracy: 0.5169
# Epoch 2/20
# 574/574 [==============================] - 276s 480ms/step - loss: 2.4938 - Precision: 0.6420 - Recall: 0.6161 - Specificity: 0.9806 - Sensitivity: 0.8327 - accuracy: 0.6262 - val_loss: 2.9521 - val_Precision: 0.6766 - val_Recall: 0.6467 - val_Specificity: 0.9901 - val_Sensitivity: 0.7821 - val_accuracy: 0.6556
# Epoch 3/20
# 574/574 [==============================] - 275s 478ms/step - loss: 1.7534 - Precision: 0.7100 - Recall: 0.6837 - Specificity: 0.9899 - Sensitivity: 0.8838 - accuracy: 0.6944 - val_loss: 0.7309 - val_Precision: 0.8337 - val_Recall: 0.8028 - val_Specificity: 0.9981 - val_Sensitivity: 0.9590 - val_accuracy: 0.8146
# Epoch 4/20
# 574/574 [==============================] - 272s 474ms/step - loss: 1.4188 - Precision: 0.7508 - Recall: 0.7248 - Specificity: 0.9933 - Sensitivity: 0.9058 - accuracy: 0.7353 - val_loss: 1.2058 - val_Precision: 0.7506 - val_Recall: 0.7293 - val_Specificity: 0.9927 - val_Sensitivity: 0.9178 - val_accuracy: 0.7372
# Epoch 5/20
# 574/574 [==============================] - 272s 474ms/step - loss: 1.2121 - Precision: 0.7745 - Recall: 0.7503 - Specificity: 0.9946 - Sensitivity: 0.9236 - accuracy: 0.7603 - val_loss: 0.7031 - val_Precision: 0.8174 - val_Recall: 0.7930 - val_Specificity: 0.9975 - val_Sensitivity: 0.9647 - val_accuracy: 0.8020
# Epoch 6/20
# 574/574 [==============================] - 272s 473ms/step - loss: 1.0293 - Precision: 0.7931 - Recall: 0.7683 - Specificity: 0.9961 - Sensitivity: 0.9375 - accuracy: 0.7774 - val_loss: 0.4900 - val_Precision: 0.8706 - val_Recall: 0.8393 - val_Specificity: 0.9991 - val_Sensitivity: 0.9810 - val_accuracy: 0.8537
# Epoch 7/20
# 574/574 [==============================] - 271s 472ms/step - loss: 1.0157 - Precision: 0.8001 - Recall: 0.7769 - Specificity: 0.9960 - Sensitivity: 0.9385 - accuracy: 0.7865 - val_loss: 0.6378 - val_Precision: 0.8484 - val_Recall: 0.8238 - val_Specificity: 0.9986 - val_Sensitivity: 0.9658 - val_accuracy: 0.8327
# Epoch 8/20
# 574/574 [==============================] - 271s 473ms/step - loss: 0.8613 - Precision: 0.8174 - Recall: 0.7950 - Specificity: 0.9973 - Sensitivity: 0.9482 - accuracy: 0.8037 - val_loss: 0.8011 - val_Precision: 0.8211 - val_Recall: 0.7867 - val_Specificity: 0.9985 - val_Sensitivity: 0.9575 - val_accuracy: 0.7993
# Epoch 9/20
# 574/574 [==============================] - 272s 474ms/step - loss: 0.7941 - Precision: 0.8247 - Recall: 0.8016 - Specificity: 0.9975 - Sensitivity: 0.9526 - accuracy: 0.8100 - val_loss: 0.6704 - val_Precision: 0.8371 - val_Recall: 0.8081 - val_Specificity: 0.9984 - val_Sensitivity: 0.9658 - val_accuracy: 0.8203
# Epoch 10/20
# 574/574 [==============================] - 271s 472ms/step - loss: 0.7943 - Precision: 0.8315 - Recall: 0.8105 - Specificity: 0.9976 - Sensitivity: 0.9539 - accuracy: 0.8193 - val_loss: 3.0077 - val_Precision: 0.7098 - val_Recall: 0.6909 - val_Specificity: 0.9923 - val_Sensitivity: 0.8255 - val_accuracy: 0.6968
# Epoch 11/20
# 574/574 [==============================] - 272s 473ms/step - loss: 0.7739 - Precision: 0.8323 - Recall: 0.8137 - Specificity: 0.9975 - Sensitivity: 0.9550 - accuracy: 0.8209 - val_loss: 0.4281 - val_Precision: 0.8866 - val_Recall: 0.8659 - val_Specificity: 0.9992 - val_Sensitivity: 0.9843 - val_accuracy: 0.8739
# Epoch 12/20
# 574/574 [==============================] - 270s 471ms/step - loss: 0.7166 - Precision: 0.8425 - Recall: 0.8216 - Specificity: 0.9978 - Sensitivity: 0.9595 - accuracy: 0.8304 - val_loss: 1.4074 - val_Precision: 0.7395 - val_Recall: 0.7250 - val_Specificity: 0.9928 - val_Sensitivity: 0.8979 - val_accuracy: 0.7302
# Epoch 13/20
# 574/574 [==============================] - 271s 473ms/step - loss: 0.5965 - Precision: 0.8590 - Recall: 0.8395 - Specificity: 0.9988 - Sensitivity: 0.9685 - accuracy: 0.8472 - val_loss: 0.6821 - val_Precision: 0.8296 - val_Recall: 0.8094 - val_Specificity: 0.9981 - val_Sensitivity: 0.9631 - val_accuracy: 0.8188
# Epoch 14/20
# 574/574 [==============================] - 270s 471ms/step - loss: 0.6059 - Precision: 0.8544 - Recall: 0.8352 - Specificity: 0.9989 - Sensitivity: 0.9686 - accuracy: 0.8433 - val_loss: 0.5713 - val_Precision: 0.8431 - val_Recall: 0.8277 - val_Specificity: 0.9984 - val_Sensitivity: 0.9749 - val_accuracy: 0.8347
# Epoch 15/20
# 574/574 [==============================] - 271s 471ms/step - loss: 0.5823 - Precision: 0.8636 - Recall: 0.8441 - Specificity: 0.9988 - Sensitivity: 0.9696 - accuracy: 0.8520 - val_loss: 0.6474 - val_Precision: 0.8476 - val_Recall: 0.8299 - val_Specificity: 0.9989 - val_Sensitivity: 0.9647 - val_accuracy: 0.8349
# Epoch 16/20
# 574/574 [==============================] - 272s 473ms/step - loss: 0.5113 - Precision: 0.8729 - Recall: 0.8529 - Specificity: 0.9991 - Sensitivity: 0.9758 - accuracy: 0.8610 - val_loss: 0.4407 - val_Precision: 0.8815 - val_Recall: 0.8635 - val_Specificity: 0.9990 - val_Sensitivity: 0.9802 - val_accuracy: 0.8694
# Epoch 17/20
# 574/574 [==============================] - 273s 475ms/step - loss: 0.5395 - Precision: 0.8689 - Recall: 0.8501 - Specificity: 0.9989 - Sensitivity: 0.9727 - accuracy: 0.8580 - val_loss: 0.5874 - val_Precision: 0.8551 - val_Recall: 0.8338 - val_Specificity: 0.9989 - val_Sensitivity: 0.9712 - val_accuracy: 0.8414
# Epoch 18/20
# 574/574 [==============================] - 272s 475ms/step - loss: 0.5497 - Precision: 0.8711 - Recall: 0.8511 - Specificity: 0.9989 - Sensitivity: 0.9741 - accuracy: 0.8596 - val_loss: 0.6397 - val_Precision: 0.8261 - val_Recall: 0.8131 - val_Specificity: 0.9974 - val_Sensitivity: 0.9688 - val_accuracy: 0.8205
# Epoch 19/20
# 574/574 [==============================] - 271s 473ms/step - loss: 0.4379 - Precision: 0.8873 - Recall: 0.8691 - Specificity: 0.9993 - Sensitivity: 0.9808 - accuracy: 0.8753 - val_loss: 0.4211 - val_Precision: 0.8903 - val_Recall: 0.8704 - val_Specificity: 0.9994 - val_Sensitivity: 0.9836 - val_accuracy: 0.8779
# Epoch 20/20
# 574/574 [==============================] - 271s 472ms/step - loss: 0.4790 - Precision: 0.8833 - Recall: 0.8657 - Specificity: 0.9992 - Sensitivity: 0.9779 - accuracy: 0.8727 - val_loss: 0.6565 - val_Precision: 0.8380 - val_Recall: 0.8222 - val_Specificity: 0.9978 - val_Sensitivity: 0.9631 - val_accuracy: 0.8288

# %%
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss(Vgg19)')

# %%
# plot the precision
plt.plot(r.history['Precision'], label='train precision')
plt.plot(r.history['val_Precision'], label='val precision')
plt.legend()
plt.show()
plt.savefig('PrecisionVal_precision(Vgg19)')

# %%
# plot the recall
plt.plot(r.history['Recall'], label='train recall')
plt.plot(r.history['val_Recall'], label='val recall')
plt.legend()
plt.show()
plt.savefig('RecallVal_recall(Vgg19)')

# %%
# plot the specificity_at_sensitivity
plt.plot(r.history['Specificity'], label='train specificity')
plt.plot(r.history['val_Specificity'], label='val specificity')
plt.legend()
plt.show()
plt.savefig('Specificity(Vgg19)')

# %%
# plot the sensitivity_at_specificity
plt.plot(r.history['Sensitivity'], label='train sensitivity')
plt.plot(r.history['val_Sensitivity'], label='val sensitivity')
plt.legend()
plt.show()
plt.savefig('sensitivity(Vgg19)')

# %%
# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc(Vgg19)')
